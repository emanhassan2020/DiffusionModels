# %% [markdown]
# <a href="https://colab.research.google.com/github/emanhassan2020/DiffusionModels/blob/main/Agents/AgenticRAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas langchain langchain-community sentence-transformers faiss-cpu smolagents --upgrade -q

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
import datasets

knowledge_base = datasets.load_dataset("m-ric/huggingface_doc", split="train")
